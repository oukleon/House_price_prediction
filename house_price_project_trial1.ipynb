# %% [markdown]
# '''
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
#        RP	Residential Low Density Park
#        RM	Residential Medium Density
#
# LotFrontage: Linear feet of street connected to property
#
# LotArea: Lot size in square feet
#
# Street: Type of road access to property
#
#        Grvl	Gravel
#        Pave	Paved
#
# Alley: Type of alley access to property
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access
#
# LotShape: General shape of property
#
#        Reg	Regular
#        IR1	Slightly irregular
#        IR2	Moderately Irregular
#        IR3	Irregular
#
# LandContour: Flatness of the property
#
#        Lvl	Near Flat/Level
#        Bnk	Banked - Quick and significant rise from street grade to building
#        HLS	Hillside - Significant slope from side to side
#        Low	Depression
#
# Utilities: Type of utilities available
#
#        AllPub	All public Utilities (E,G,W,& S)
#        NoSewr	Electricity, Gas, and Water (Septic Tank)
#        NoSeWa	Electricity and Gas Only
#        ELO	Electricity only
#
# LotConfig: Lot configuration
#
#        Inside	Inside lot
#        Corner	Corner lot
#        CulDSac	Cul-de-sac
#        FR2	Frontage on 2 sides of property
#        FR3	Frontage on 3 sides of property
#
# LandSlope: Slope of property
#
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
#
# Neighborhood: Physical locations within Ames city limits
#
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker
#
# Condition1: Proximity to various conditions
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# Condition2: Proximity to various conditions (if more than one is present)
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# BldgType: Type of dwelling
#
#        1Fam	Single-family Detached
#        2FmCon	Two-family Conversion; originally built as one-family dwelling
#        Duplx	Duplex
#        TwnhsE	Townhouse End Unit
#        TwnhsI	Townhouse Inside Unit
#
# HouseStyle: Style of dwelling
#
#        1Story	One story
#        1.5Fin	One and one-half story: 2nd level finished
#        1.5Unf	One and one-half story: 2nd level unfinished
#        2Story	Two story
#        2.5Fin	Two and one-half story: 2nd level finished
#        2.5Unf	Two and one-half story: 2nd level unfinished
#        SFoyer	Split Foyer
#        SLvl	Split Level
#
# OverallQual: Rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# OverallCond: Rates the overall condition of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# YearBuilt: Original construction date
#
# YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)
#
# RoofStyle: Type of roof
#
#        Flat	Flat
#        Gable	Gable
#        Gambrel	Gabrel (Barn)
#        Hip	Hip
#        Mansard	Mansard
#        Shed	Shed
#
# RoofMatl: Roof material
#
#        ClyTile	Clay or Tile
#        CompShg	Standard (Composite) Shingle
#        Membran	Membrane
#        Metal	Metal
#        Roll	Roll
#        Tar&Grv	Gravel & Tar
#        WdShake	Wood Shakes
#        WdShngl	Wood Shingles
#
# Exterior1st: Exterior covering on house
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# Exterior2nd: Exterior covering on house (if more than one material)
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# MasVnrType: Masonry veneer type
#
#        BrkCmn	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        None	None
#        Stone	Stone
#
# MasVnrArea: Masonry veneer area in square feet
#
# ExterQual: Evaluates the quality of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# ExterCond: Evaluates the present condition of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# Foundation: Type of foundation
#
#        BrkTil	Brick & Tile
#        CBlock	Cinder Block
#        PConc	Poured Contrete
#        Slab	Slab
#        Stone	Stone
#        Wood	Wood
#
# BsmtQual: Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement
#
# BsmtCond: Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement
#
# BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
#
# BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF1: Type 1 finished square feet
#
# BsmtFinType2: Rating of basement finished area (if multiple types)
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF2: Type 2 finished square feet
#
# BsmtUnfSF: Unfinished square feet of basement area
#
# TotalBsmtSF: Total square feet of basement area
#
# Heating: Type of heating
#
#        Floor	Floor Furnace
#        GasA	Gas forced warm air furnace
#        GasW	Gas hot water or steam heat
#        Grav	Gravity furnace
#        OthW	Hot water or steam heat other than gas
#        Wall	Wall furnace
#
# HeatingQC: Heating quality and condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# CentralAir: Central air conditioning
#
#        N	No
#        Y	Yes
#
# Electrical: Electrical system
#
#        SBrkr	Standard Circuit Breakers & Romex
#        FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
#        FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
#        FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
#        Mix	Mixed
#
# 1stFlrSF: First Floor square feet
#
# 2ndFlrSF: Second floor square feet
#
# LowQualFinSF: Low quality finished square feet (all floors)
#
# GrLivArea: Above grade (ground) living area square feet
#
# BsmtFullBath: Basement full bathrooms
#
# BsmtHalfBath: Basement half bathrooms
#
# FullBath: Full bathrooms above grade
#
# HalfBath: Half baths above grade
#
# Bedroom: Bedrooms above grade (does NOT include basement bedrooms)
#
# Kitchen: Kitchens above grade
#
# KitchenQual: Kitchen quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
#        Typ	Typical Functionality
#        Min1	Minor Deductions 1
#        Min2	Minor Deductions 2
#        Mod	Moderate Deductions
#        Maj1	Major Deductions 1
#        Maj2	Major Deductions 2
#        Sev	Severely Damaged
#        Sal	Salvage only
#
# Fireplaces: Number of fireplaces
#
# FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace
#
# GarageType: Garage location
#
#        2Types	More than one type of garage
#        Attchd	Attached to home
#        Basment	Basement Garage
#        BuiltIn	Built-In (Garage part of house - typically has room above garage)
#        CarPort	Car Port
#        Detchd	Detached from home
#        NA	No Garage
#
# GarageYrBlt: Year garage was built
#
# GarageFinish: Interior finish of the garage
#
#        Fin	Finished
#        RFn	Rough Finished
#        Unf	Unfinished
#        NA	No Garage
#
# GarageCars: Size of garage in car capacity
#
# GarageArea: Size of garage in square feet
#
# GarageQual: Garage quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# GarageCond: Garage condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# PavedDrive: Paved driveway
#
#        Y	Paved
#        P	Partial Pavement
#        N	Dirt/Gravel
#
# WoodDeckSF: Wood deck area in square feet
#
# OpenPorchSF: Open porch area in square feet
#
# EnclosedPorch: Enclosed porch area in square feet
#
# 3SsnPorch: Three season porch area in square feet
#
# ScreenPorch: Screen porch area in square feet
#
# PoolArea: Pool area in square feet
#
# PoolQC: Pool quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        NA	No Pool
#
# Fence: Fence quality
#
#        GdPrv	Good Privacy
#        MnPrv	Minimum Privacy
#        GdWo	Good Wood
#        MnWw	Minimum Wood/Wire
#        NA	No Fence
#
# MiscFeature: Miscellaneous feature not covered in other categories
#
#        Elev	Elevator
#        Gar2	2nd Garage (if not described in garage section)
#        Othr	Other
#        Shed	Shed (over 100 SF)
#        TenC	Tennis Court
#        NA	None
#
# MiscVal: $Value of miscellaneous feature
#
# MoSold: Month Sold (MM)
#
# YrSold: Year Sold (YYYY)
#
# SaleType: Type of sale
#
#        WD 	Warranty Deed - Conventional
#        CWD	Warranty Deed - Cash
#        VWD	Warranty Deed - VA Loan
#        New	Home just constructed and sold
#        COD	Court Officer Deed/Estate
#        Con	Contract 15% Down payment regular terms
#        ConLw	Contract Low Down payment and low interest
#        ConLI	Contract Low Interest
#        ConLD	Contract Low Down
#        Oth	Other
#
# SaleCondition: Condition of sale
#
#        Normal	Normal Sale
#        Abnorml	Abnormal Sale -  trade, foreclosure, short sale
#        AdjLand	Adjoining Land Purchase
#        Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage unit
#        Family	Sale between family members
#        Partial	Home was not completed when last assessed (associated with New Homes)
#
# '''

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('E:/Datasets/house_prices/train.csv')
df_test=pd.read_csv('E:/Datasets/house_prices/test.csv')

# %% [markdown]
# ## Data preprocessing

# %%
df.shape
# Out:
# (1460, 81)

# %%
df_test.shape
# Out:
# (1459, 80)

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
#num:38, object:43
cate=df.select_dtypes(include='object')
nume=df.select_dtypes(exclude='object')

# %% [markdown]
# ### Fillna & Remove irrelevant features

# %%
# I went with whole dataframe at the first trial and since there are too many features, I could not show clear numbers with figures. Thus, I am going to do visualization after handling all the data with separating numerical and categorical features

# %% [markdown]
# #### Numerical features

# %%
nume.corr()['SalePrice'].sort_values()
# Out:
# KitchenAbvGr    -0.135907
# EnclosedPorch   -0.128578
# MSSubClass      -0.084284
# OverallCond     -0.077856
# YrSold          -0.028923
# LowQualFinSF    -0.025606
# Id              -0.021917
# MiscVal         -0.021190
# BsmtHalfBath    -0.016844
# BsmtFinSF2      -0.011378
# 3SsnPorch        0.044584
# MoSold           0.046432
# PoolArea         0.092404
# ScreenPorch      0.111447
# BedroomAbvGr     0.168213
# BsmtUnfSF        0.214479
# BsmtFullBath     0.227122
# LotArea          0.263843
# HalfBath         0.284108
# OpenPorchSF      0.315856
# 2ndFlrSF         0.319334
# WoodDeckSF       0.324413
# LotFrontage      0.351799
# BsmtFinSF1       0.386420
# Fireplaces       0.466929
# MasVnrArea       0.477493
# GarageYrBlt      0.486362
# YearRemodAdd     0.507101
# YearBuilt        0.522897
# TotRmsAbvGrd     0.533723
# FullBath         0.560664
# 1stFlrSF         0.605852
# TotalBsmtSF      0.613581
# GarageArea       0.623431
# GarageCars       0.640409
# GrLivArea        0.708624
# OverallQual      0.790982
# SalePrice        1.000000
# Name: SalePrice, dtype: float64

# %%
nume=nume.set_index('Id')

# %%
#drop the low correlation to saleprice -> even id has 2.2 percents correlation, thus i dropped out lower than 5 percents features.
df_lowcor=abs(nume.corr()['SalePrice'])<0.05
df_lowcor_col=df[df_lowcor.index[df_lowcor]].columns

# %%
df_lowcor_col
# Out:
# Index(['BsmtFinSF2', 'LowQualFinSF', 'BsmtHalfBath', '3SsnPorch', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')

# %%
nume.drop(nume[df_lowcor_col],axis=1,inplace=True)
df.drop(df[df_lowcor_col],axis=1,inplace=True)
df_test.drop(df_test[df_lowcor_col],axis=1,inplace=True)

# %%
nume.MasVnrArea.fillna(nume.MasVnrArea.mode()[0],inplace=True)
df.MasVnrArea.fillna(df.MasVnrArea.mode()[0],inplace=True)

# %%
nume.GarageYrBlt.value_counts().head(10)
# Out:
# 2005.0    65
# 2006.0    59
# 2004.0    53
# 2003.0    50
# 2007.0    49
# 1977.0    35
# 1998.0    31
# 1999.0    30
# 2008.0    29
# 1976.0    29
# Name: GarageYrBlt, dtype: int64

# %%
nume.loc[nume.GarageYrBlt.isna()]
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 40            90         65.0     6040            4            5       1955
# 49           190         33.0     4456            4            5       1920
# 79            90         72.0    10778            4            5       1968
# 89            50        105.0     8470            3            2       1915
# 90            20         60.0     8070            4            5       1994
# ...          ...          ...      ...          ...          ...        ...
# 1350          70         50.0     5250            8            5       1872
# 1408          20          NaN     8780            5            5       1985
# 1450         180         21.0     1533            5            7       1970
# 1451          90         60.0     9000            5            5       1974
# 1454          20         90.0    17217            5            5       2006
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtUnfSF  ...  Fireplaces  \
# Id                                                     ...
# 40            1955         0.0           0          0  ...           0
# 49            2008         0.0           0        736  ...           0
# 79            1968         0.0           0       1768  ...           0
# 89            1982         0.0           0       1013  ...           0
# 90            1995         0.0         588        402  ...           0
# ...            ...         ...         ...        ...  ...         ...
# 1350          1987         0.0         259        425  ...           0
# 1408          1985         0.0         625        208  ...           0
# 1450          1970         0.0         553         77  ...           0
# 1451          1974         0.0           0        896  ...           0
# 1454          2006         0.0           0       1140  ...           0
#
#       GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# Id
# 40            NaN           0           0           0            0
# 49            NaN           0           0           0            0
# 79            NaN           0           0           0            0
# 89            NaN           0           0           0            0
# 90            NaN           0           0           0            0
# ...           ...         ...         ...         ...          ...
# 1350          NaN           0           0           0           54
# 1408          NaN           0           0           0            0
# 1450          NaN           0           0           0            0
# 1451          NaN           0           0          32           45
# 1454          NaN           0           0          36           56
#
#       EnclosedPorch  ScreenPorch  PoolArea  SalePrice
# Id
# 40                0            0         0      82000
# 49              102            0         0     113000
# 79                0            0         0     136500
# 89              156            0         0      85000
# 90                0            0         0     123600
# ...             ...          ...       ...        ...
# 1350             20            0         0     122000
# 1408              0            0         0     112000
# 1450              0            0         0      92000
# 1451              0            0         0     136000
# 1454              0            0         0      84500
#
# [81 rows x 30 columns]

# %%
nume.corr()['GarageYrBlt'].sort_values()
# Out:
# OverallCond     -0.324297
# EnclosedPorch   -0.297003
# KitchenAbvGr    -0.124411
# ScreenPorch     -0.075418
# BedroomAbvGr    -0.064518
# LotArea         -0.024947
# PoolArea        -0.014501
# Fireplaces       0.046822
# LotFrontage      0.070250
# 2ndFlrSF         0.070832
# MSSubClass       0.085072
# BsmtFullBath     0.124553
# TotRmsAbvGrd     0.148112
# BsmtFinSF1       0.153484
# BsmtUnfSF        0.190708
# HalfBath         0.196785
# WoodDeckSF       0.224577
# OpenPorchSF      0.228425
# GrLivArea        0.231197
# 1stFlrSF         0.233449
# MasVnrArea       0.248546
# TotalBsmtSF      0.322445
# FullBath         0.484557
# SalePrice        0.486362
# OverallQual      0.547766
# GarageArea       0.564567
# GarageCars       0.588920
# YearRemodAdd     0.642277
# YearBuilt        0.825667
# GarageYrBlt      1.000000
# Name: GarageYrBlt, dtype: float64

# %%
nume.YearBuilt #fillna with yearbuilt that has 82.5 percents correlation. means most likely same year to build main property and garage together
# Out:
# Id
# 1       2003
# 2       1976
# 3       2001
# 4       1915
# 5       2000
#         ...
# 1456    1999
# 1457    1978
# 1458    1941
# 1459    1950
# 1460    1965
# Name: YearBuilt, Length: 1460, dtype: int64

# %%
nume.GarageYrBlt.fillna(nume.YearBuilt,inplace=True)
df.GarageYrBlt.fillna(df.YearBuilt,inplace=True)

# %%
nume
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1             60         65.0     8450            7            5       2003
# 2             20         80.0     9600            6            8       1976
# 3             60         68.0    11250            7            5       2001
# 4             70         60.0     9550            7            5       1915
# 5             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1456          60         62.0     7917            6            5       1999
# 1457          20         85.0    13175            6            6       1978
# 1458          70         66.0     9042            7            9       1941
# 1459          20         68.0     9717            5            6       1950
# 1460          20         75.0     9937            5            6       1965
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtUnfSF  ...  Fireplaces  \
# Id                                                     ...
# 1             2003       196.0         706        150  ...           0
# 2             1976         0.0         978        284  ...           1
# 3             2002       162.0         486        434  ...           1
# 4             1970         0.0         216        540  ...           1
# 5             2000       350.0         655        490  ...           1
# ...            ...         ...         ...        ...  ...         ...
# 1456          2000         0.0           0        953  ...           1
# 1457          1988       119.0         790        589  ...           2
# 1458          2006         0.0         275        877  ...           2
# 1459          1996         0.0          49          0  ...           0
# 1460          1965         0.0         830        136  ...           0
#
#       GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# Id
# 1          2003.0           2         548           0           61
# 2          1976.0           2         460         298            0
# 3          2001.0           2         608           0           42
# 4          1998.0           3         642           0           35
# 5          2000.0           3         836         192           84
# ...           ...         ...         ...         ...          ...
# 1456       1999.0           2         460           0           40
# 1457       1978.0           2         500         349            0
# 1458       1941.0           1         252           0           60
# 1459       1950.0           1         240         366            0
# 1460       1965.0           1         276         736           68
#
#       EnclosedPorch  ScreenPorch  PoolArea  SalePrice
# Id
# 1                 0            0         0     208500
# 2                 0            0         0     181500
# 3                 0            0         0     223500
# 4               272            0         0     140000
# 5                 0            0         0     250000
# ...             ...          ...       ...        ...
# 1456              0            0         0     175000
# 1457              0            0         0     210000
# 1458              0            0         0     266500
# 1459            112            0         0     142125
# 1460              0            0         0     147500
#
# [1460 rows x 30 columns]

# %%
nume.LotFrontage.isna().sum()
# Out:
# 259

# %%
nume.LotFrontage.value_counts()
# Out:
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 106.0      1
# 38.0       1
# 138.0      1
# 140.0      1
# 137.0      1
# Name: LotFrontage, Length: 110, dtype: int64

# %%
nume.corr()['SalePrice'] #0.352
# Out:
# MSSubClass      -0.084284
# LotFrontage      0.351799
# LotArea          0.263843
# OverallQual      0.790982
# OverallCond     -0.077856
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.472614
# BsmtFinSF1       0.386420
# BsmtUnfSF        0.214479
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# 2ndFlrSF         0.319334
# GrLivArea        0.708624
# BsmtFullBath     0.227122
# FullBath         0.560664
# HalfBath         0.284108
# BedroomAbvGr     0.168213
# KitchenAbvGr    -0.135907
# TotRmsAbvGrd     0.533723
# Fireplaces       0.466929
# GarageYrBlt      0.508043
# GarageCars       0.640409
# GarageArea       0.623431
# WoodDeckSF       0.324413
# OpenPorchSF      0.315856
# EnclosedPorch   -0.128578
# ScreenPorch      0.111447
# PoolArea         0.092404
# SalePrice        1.000000
# Name: SalePrice, dtype: float64

# %%
df['LotFrontage'].fillna(df['LotFrontage'].median(),inplace=True)
nume['LotFrontage'].fillna(nume['LotFrontage'].median(),inplace=True)

# %%
nume.corr()['SalePrice'] #0.334.  Dropping 1.8 percents correlation. Fillna with median doesnt harm much with making saleprice.
# Out:
# MSSubClass      -0.084284
# LotFrontage      0.334771
# LotArea          0.263843
# OverallQual      0.790982
# OverallCond     -0.077856
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.472614
# BsmtFinSF1       0.386420
# BsmtUnfSF        0.214479
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# 2ndFlrSF         0.319334
# GrLivArea        0.708624
# BsmtFullBath     0.227122
# FullBath         0.560664
# HalfBath         0.284108
# BedroomAbvGr     0.168213
# KitchenAbvGr    -0.135907
# TotRmsAbvGrd     0.533723
# Fireplaces       0.466929
# GarageYrBlt      0.508043
# GarageCars       0.640409
# GarageArea       0.623431
# WoodDeckSF       0.324413
# OpenPorchSF      0.315856
# EnclosedPorch   -0.128578
# ScreenPorch      0.111447
# PoolArea         0.092404
# SalePrice        1.000000
# Name: SalePrice, dtype: float64

# %%
nume
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1             60         65.0     8450            7            5       2003
# 2             20         80.0     9600            6            8       1976
# 3             60         68.0    11250            7            5       2001
# 4             70         60.0     9550            7            5       1915
# 5             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1456          60         62.0     7917            6            5       1999
# 1457          20         85.0    13175            6            6       1978
# 1458          70         66.0     9042            7            9       1941
# 1459          20         68.0     9717            5            6       1950
# 1460          20         75.0     9937            5            6       1965
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtUnfSF  ...  Fireplaces  \
# Id                                                     ...
# 1             2003       196.0         706        150  ...           0
# 2             1976         0.0         978        284  ...           1
# 3             2002       162.0         486        434  ...           1
# 4             1970         0.0         216        540  ...           1
# 5             2000       350.0         655        490  ...           1
# ...            ...         ...         ...        ...  ...         ...
# 1456          2000         0.0           0        953  ...           1
# 1457          1988       119.0         790        589  ...           2
# 1458          2006         0.0         275        877  ...           2
# 1459          1996         0.0          49          0  ...           0
# 1460          1965         0.0         830        136  ...           0
#
#       GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# Id
# 1          2003.0           2         548           0           61
# 2          1976.0           2         460         298            0
# 3          2001.0           2         608           0           42
# 4          1998.0           3         642           0           35
# 5          2000.0           3         836         192           84
# ...           ...         ...         ...         ...          ...
# 1456       1999.0           2         460           0           40
# 1457       1978.0           2         500         349            0
# 1458       1941.0           1         252           0           60
# 1459       1950.0           1         240         366            0
# 1460       1965.0           1         276         736           68
#
#       EnclosedPorch  ScreenPorch  PoolArea  SalePrice
# Id
# 1                 0            0         0     208500
# 2                 0            0         0     181500
# 3                 0            0         0     223500
# 4               272            0         0     140000
# 5                 0            0         0     250000
# ...             ...          ...       ...        ...
# 1456              0            0         0     175000
# 1457              0            0         0     210000
# 1458              0            0         0     266500
# 1459            112            0         0     142125
# 1460              0            0         0     147500
#
# [1460 rows x 30 columns]

# %%
nume_corr=nume.corr()

# %%
plt.figure(figsize=(30,18))
sns.heatmap(nume_corr,annot=True,cmap='coolwarm')

# %%
#yearbuilt and garageyrblt has 0.85 which is pretty high correlation with each features that is potentially harmful for redundant info. However, 85 percents does not mean too much redundant(in most of my projects, i dropped with 0.9 threshold) to bring for training

# %% [markdown]
# #### Categorical features

# %%
cate
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1  ... GarageType GarageFinish GarageQual  \
# 0         CollgCr       Norm  ...     Attchd          RFn         TA
# 1         Veenker      Feedr  ...     Attchd          RFn         TA
# 2         CollgCr       Norm  ...     Attchd          RFn         TA
# 3         Crawfor       Norm  ...     Detchd          Unf         TA
# 4         NoRidge       Norm  ...     Attchd          RFn         TA
# ...           ...        ...  ...        ...          ...        ...
# 1455      Gilbert       Norm  ...     Attchd          RFn         TA
# 1456       NWAmes       Norm  ...     Attchd          Unf         TA
# 1457      Crawfor       Norm  ...     Attchd          RFn         TA
# 1458        NAmes       Norm  ...     Attchd          Unf         TA
# 1459      Edwards       Norm  ...     Attchd          Fin         TA
#
#      GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType SaleCondition
# 0            TA          Y    NaN    NaN         NaN       WD        Normal
# 1            TA          Y    NaN    NaN         NaN       WD        Normal
# 2            TA          Y    NaN    NaN         NaN       WD        Normal
# 3            TA          Y    NaN    NaN         NaN       WD       Abnorml
# 4            TA          Y    NaN    NaN         NaN       WD        Normal
# ...         ...        ...    ...    ...         ...      ...           ...
# 1455         TA          Y    NaN    NaN         NaN       WD        Normal
# 1456         TA          Y    NaN  MnPrv         NaN       WD        Normal
# 1457         TA          Y    NaN  GdPrv        Shed       WD        Normal
# 1458         TA          Y    NaN    NaN         NaN       WD        Normal
# 1459         TA          Y    NaN    NaN         NaN       WD        Normal
#
# [1460 rows x 43 columns]

# %%
# identify bias features with one value (over 80 percents) 
leng=len(cate)
max_counts={}
for i in cate:
    max_cate=cate[i].value_counts()[0]/leng
    max_counts.update({i:max_cate})
print(max_counts)
# Out:
# {'MSZoning': 0.7883561643835616, 'Street': 0.9958904109589041, 'Alley': 0.03424657534246575, 'LotShape': 0.6335616438356164, 'LandContour': 0.897945205479452, 'Utilities': 0.9993150684931507, 'LotConfig': 0.7205479452054795, 'LandSlope': 0.9465753424657535, 'Neighborhood': 0.1541095890410959, 'Condition1': 0.863013698630137, 'Condition2': 0.9897260273972602, 'BldgType': 0.8356164383561644, 'HouseStyle': 0.49726027397260275, 'RoofStyle': 0.7815068493150685, 'RoofMatl': 0.9821917808219178, 'Exterior1st': 0.3527397260273973, 'Exterior2nd': 0.3452054794520548, 'MasVnrType': 0.5917808219178082, 'ExterQual': 0.6205479452054794, 'ExterCond': 0.8780821917808219, 'Foundation': 0.44315068493150683, 'BsmtQual': 0.44452054794520546, 'BsmtCond': 0.897945205479452, 'BsmtExposure': 0.6527397260273973, 'BsmtFinType1': 0.2945205479452055, 'BsmtFinType2': 0.8602739726027397, 'Heating': 0.9780821917808219, 'HeatingQC': 0.5075342465753425, 'CentralAir': 0.934931506849315, 'Electrical': 0.9136986301369863, 'KitchenQual': 0.5034246575342466, 'Functional': 0.9315068493150684, 'FireplaceQu': 0.2602739726027397, 'GarageType': 0.5958904109589042, 'GarageFinish': 0.4143835616438356, 'GarageQual': 0.897945205479452, 'GarageCond': 0.9082191780821918, 'PavedDrive': 0.9178082191780822, 'PoolQC': 0.002054794520547945, 'Fence': 0.10753424657534247, 'MiscFeature': 0.03356164383561644, 'SaleType': 0.8678082191780822, 'SaleCondition': 0.8205479452054795}

# %%
sorted(max_counts.items(),key=lambda item:item[1])
# Out:
# [('PoolQC', 0.002054794520547945),
#  ('MiscFeature', 0.03356164383561644),
#  ('Alley', 0.03424657534246575),
#  ('Fence', 0.10753424657534247),
#  ('Neighborhood', 0.1541095890410959),
#  ('FireplaceQu', 0.2602739726027397),
#  ('BsmtFinType1', 0.2945205479452055),
#  ('Exterior2nd', 0.3452054794520548),
#  ('Exterior1st', 0.3527397260273973),
#  ('GarageFinish', 0.4143835616438356),
#  ('Foundation', 0.44315068493150683),
#  ('BsmtQual', 0.44452054794520546),
#  ('HouseStyle', 0.49726027397260275),
#  ('KitchenQual', 0.5034246575342466),
#  ('HeatingQC', 0.5075342465753425),
#  ('MasVnrType', 0.5917808219178082),
#  ('GarageType', 0.5958904109589042),
#  ('ExterQual', 0.6205479452054794),
#  ('LotShape', 0.6335616438356164),
#  ('BsmtExposure', 0.6527397260273973),
#  ('LotConfig', 0.7205479452054795),
#  ('RoofStyle', 0.7815068493150685),
#  ('MSZoning', 0.7883561643835616),
#  ('SaleCondition', 0.8205479452054795),
#  ('BldgType', 0.8356164383561644),
#  ('BsmtFinType2', 0.8602739726027397),
#  ('Condition1', 0.863013698630137),
#  ('SaleType', 0.8678082191780822),
#  ('ExterCond', 0.8780821917808219),
#  ('LandContour', 0.897945205479452),
#  ('BsmtCond', 0.897945205479452),
#  ('GarageQual', 0.897945205479452),
#  ('GarageCond', 0.9082191780821918),
#  ('Electrical', 0.9136986301369863),
#  ('PavedDrive', 0.9178082191780822),
#  ('Functional', 0.9315068493150684),
#  ('CentralAir', 0.934931506849315),
#  ('LandSlope', 0.9465753424657535),
#  ('Heating', 0.9780821917808219),
#  ('RoofMatl', 0.9821917808219178),
#  ('Condition2', 0.9897260273972602),
#  ('Street', 0.9958904109589041),
#  ('Utilities', 0.9993150684931507)]

# %%
#Getting rid of columns having too much portion with one value
bias_col=[]
for i in max_counts.items():
    if i[1] >0.80:
        bias_col.append(i[0])
# print(bias_col)
cate.drop(bias_col,axis=1,inplace=True)
df.drop(bias_col,axis=1,inplace=True)
df_test.drop(bias_col,axis=1,inplace=True)
# Out:
# C:\Users\oukle\Anaconda3\lib\site-packages\pandas\core\frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
cate[cate.columns[cate.isna().sum()!=0]]
# Out:
#      Alley MasVnrType BsmtQual BsmtExposure BsmtFinType1 FireplaceQu  \
# 0      NaN    BrkFace       Gd           No          GLQ         NaN
# 1      NaN       None       Gd           Gd          ALQ          TA
# 2      NaN    BrkFace       Gd           Mn          GLQ          TA
# 3      NaN       None       TA           No          ALQ          Gd
# 4      NaN    BrkFace       Gd           Av          GLQ          TA
# ...    ...        ...      ...          ...          ...         ...
# 1455   NaN       None       Gd           No          Unf          TA
# 1456   NaN      Stone       Gd           No          ALQ          TA
# 1457   NaN       None       TA           No          GLQ          Gd
# 1458   NaN       None       TA           Mn          GLQ         NaN
# 1459   NaN       None       TA           No          BLQ         NaN
#
#      GarageType GarageFinish PoolQC  Fence MiscFeature
# 0        Attchd          RFn    NaN    NaN         NaN
# 1        Attchd          RFn    NaN    NaN         NaN
# 2        Attchd          RFn    NaN    NaN         NaN
# 3        Detchd          Unf    NaN    NaN         NaN
# 4        Attchd          RFn    NaN    NaN         NaN
# ...         ...          ...    ...    ...         ...
# 1455     Attchd          RFn    NaN    NaN         NaN
# 1456     Attchd          Unf    NaN  MnPrv         NaN
# 1457     Attchd          RFn    NaN  GdPrv        Shed
# 1458     Attchd          Unf    NaN    NaN         NaN
# 1459     Attchd          Fin    NaN    NaN         NaN
#
# [1460 rows x 11 columns]

# %%
(cate.isna().sum()/len(cate)).sort_values()
# Out:
# MSZoning        0.000000
# KitchenQual     0.000000
# HeatingQC       0.000000
# ExterQual       0.000000
# Exterior2nd     0.000000
# Exterior1st     0.000000
# Foundation      0.000000
# HouseStyle      0.000000
# Neighborhood    0.000000
# LotConfig       0.000000
# LotShape        0.000000
# RoofStyle       0.000000
# MasVnrType      0.005479
# BsmtQual        0.025342
# BsmtFinType1    0.025342
# BsmtExposure    0.026027
# GarageType      0.055479
# GarageFinish    0.055479
# FireplaceQu     0.472603
# Fence           0.807534
# Alley           0.937671
# MiscFeature     0.963014
# PoolQC          0.995205
# dtype: float64

# %%
# drop the columns with more than 40% Nan
cate.drop(['Alley','PoolQC','Fence','FireplaceQu','MiscFeature'],axis=1,inplace=True)
df.drop(['Alley','PoolQC','Fence','FireplaceQu','MiscFeature'],axis=1,inplace=True)
df_test.drop(['Alley','PoolQC','Fence','FireplaceQu','MiscFeature'],axis=1,inplace=True)
# Out:
# C:\Users\oukle\Anaconda3\lib\site-packages\pandas\core\frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
(cate.isna().sum()/len(cate)).sort_values()
# Out:
# MSZoning        0.000000
# LotShape        0.000000
# LotConfig       0.000000
# Neighborhood    0.000000
# HouseStyle      0.000000
# RoofStyle       0.000000
# Exterior1st     0.000000
# Exterior2nd     0.000000
# KitchenQual     0.000000
# ExterQual       0.000000
# Foundation      0.000000
# HeatingQC       0.000000
# MasVnrType      0.005479
# BsmtFinType1    0.025342
# BsmtQual        0.025342
# BsmtExposure    0.026027
# GarageType      0.055479
# GarageFinish    0.055479
# dtype: float64

# %%
cate.GarageFinish.value_counts()
# Out:
# Unf    605
# RFn    422
# Fin    352
# Name: GarageFinish, dtype: int64

# %%
cate.GarageFinish.fillna(cate.GarageFinish.mode()[0],inplace=True)
df.GarageFinish.fillna(df.GarageFinish.mode()[0],inplace=True)
# Out:
# C:\Users\oukle\Anaconda3\lib\site-packages\pandas\core\series.py:4523: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
cate.GarageType.value_counts()
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
cate.GarageType.fillna(cate.GarageType.mode()[0],inplace=True)
df.GarageType.fillna(df.GarageType.mode()[0],inplace=True)

# %%
cate.BsmtExposure.value_counts()
# Out:
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64

# %%
cate.BsmtExposure.fillna(cate.BsmtExposure.mode()[0],inplace=True)
df.BsmtExposure.fillna(df.BsmtExposure.mode()[0],inplace=True)

# %%
cate.MasVnrType.value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
cate.MasVnrType.fillna(cate.MasVnrType.mode()[0],inplace=True)
df.MasVnrType.fillna(df.MasVnrType.mode()[0],inplace=True)

# %%
'''
BsmtFinType1: Rating of basement finished area

   GLQ    Good Living Quarters
   ALQ    Average Living Quarters
   BLQ    Below Average Living Quarters    
   Rec    Average Rec Room
   LwQ    Low Quality
   Unf    Unfinshed
   NA    No Basement
'''
# Out:
# '\nBsmtFinType1: Rating of basement finished area\n\n   GLQ    Good Living Quarters\n   ALQ    Average Living Quarters\n   BLQ    Below Average Living Quarters    \n   Rec    Average Rec Room\n   LwQ    Low Quality\n   Unf    Unfinshed\n   NA    No Basement\n'

# %%
cate.BsmtFinType1.value_counts()
# Out:
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64

# %%
cate.BsmtQual.value_counts()
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64

# %%
cate
# Out:
#      MSZoning LotShape LotConfig Neighborhood HouseStyle RoofStyle  \
# 0          RL      Reg    Inside      CollgCr     2Story     Gable
# 1          RL      Reg       FR2      Veenker     1Story     Gable
# 2          RL      IR1    Inside      CollgCr     2Story     Gable
# 3          RL      IR1    Corner      Crawfor     2Story     Gable
# 4          RL      IR1       FR2      NoRidge     2Story     Gable
# ...       ...      ...       ...          ...        ...       ...
# 1455       RL      Reg    Inside      Gilbert     2Story     Gable
# 1456       RL      Reg    Inside       NWAmes     1Story     Gable
# 1457       RL      Reg    Inside      Crawfor     2Story     Gable
# 1458       RL      Reg    Inside        NAmes     1Story       Hip
# 1459       RL      Reg    Inside      Edwards     1Story     Gable
#
#      Exterior1st Exterior2nd MasVnrType ExterQual Foundation BsmtQual  \
# 0        VinylSd     VinylSd    BrkFace        Gd      PConc       Gd
# 1        MetalSd     MetalSd       None        TA     CBlock       Gd
# 2        VinylSd     VinylSd    BrkFace        Gd      PConc       Gd
# 3        Wd Sdng     Wd Shng       None        TA     BrkTil       TA
# 4        VinylSd     VinylSd    BrkFace        Gd      PConc       Gd
# ...          ...         ...        ...       ...        ...      ...
# 1455     VinylSd     VinylSd       None        TA      PConc       Gd
# 1456     Plywood     Plywood      Stone        TA     CBlock       Gd
# 1457     CemntBd     CmentBd       None        Ex      Stone       TA
# 1458     MetalSd     MetalSd       None        TA     CBlock       TA
# 1459     HdBoard     HdBoard       None        Gd     CBlock       TA
#
#      BsmtExposure BsmtFinType1 HeatingQC KitchenQual GarageType GarageFinish
# 0              No          GLQ        Ex          Gd     Attchd          RFn
# 1              Gd          ALQ        Ex          TA     Attchd          RFn
# 2              Mn          GLQ        Ex          Gd     Attchd          RFn
# 3              No          ALQ        Gd          Gd     Detchd          Unf
# 4              Av          GLQ        Ex          Gd     Attchd          RFn
# ...           ...          ...       ...         ...        ...          ...
# 1455           No          Unf        Ex          TA     Attchd          RFn
# 1456           No          ALQ        TA          TA     Attchd          Unf
# 1457           No          GLQ        Ex          Gd     Attchd          RFn
# 1458           Mn          GLQ        Gd          Gd     Attchd          Unf
# 1459           No          BLQ        Gd          TA     Attchd          Fin
#
# [1460 rows x 18 columns]

# %%
plt.subplot(6,3,18)
plt.figure(figsize=(10,30))
for i in range(len(cate.columns)):
    plt.subplot(6,3,i+1)
    cate[cate.columns[i]].value_counts().plot.bar()
    plt.title("{}".format(cate.columns[i]))
plt.tight_layout()

# %%
cate_pre_saleprice=cate.copy()
cate_pre_saleprice['SalePrice']=df['SalePrice']
cate['SalePrice']=df['SalePrice']
# Out:
# C:\Users\oukle\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
cate_sales=cate_pre_saleprice.loc[cate_pre_saleprice.BsmtQual.isna()]

# %%
cate_sales.sort_values('SalePrice')
# Out:
#      MSZoning LotShape LotConfig Neighborhood HouseStyle RoofStyle  \
# 533        RL      Reg    Inside      BrkSide     1Story     Gable
# 705        RM      Reg    Inside       IDOTRR     2Story       Hip
# 1321       RL      IR1    Corner      BrkSide     1Story       Hip
# 1218       RM      Reg    Inside      BrkSide     1.5Fin     Gable
# 39         RL      Reg    Inside      Edwards     1Story     Gable
# 1000       RL      Reg    Corner      Edwards     1Story      Flat
# 1035       RL      IR1   CulDSac      Edwards     1Story     Gable
# 1049       RL      Reg    Inside      Edwards     1Story     Gable
# 342        RL      Reg    Inside        NAmes     1Story     Gable
# 17         RL      Reg    Inside       Sawyer     1Story     Gable
# 1412       RL      Reg    Inside        NAmes     1Story     Gable
# 1090       RL      Reg    Corner        NAmes     1Story     Gable
# 1179       RL      Reg    Corner      Edwards     1Story     Gable
# 736        RL      Reg    Inside        NAmes     1Story     Gable
# 259        RM      Reg    Inside      OldTown     1Story     Gable
# 749        RL      Reg    Inside      Edwards     1.5Fin     Gable
# 646        RL      Reg    Inside        NAmes     1Story       Hip
# 1011       RL      Reg    Inside      Edwards     1Story       Hip
# 1232       RL      Reg       FR2        NAmes     1Story     Gable
# 520        RL      Reg    Inside      OldTown     2Story     Gable
# 392        RL      IR1    Inside        NAmes     1Story     Gable
# 532        RL      Reg    Inside        NAmes     1Story     Gable
# 553        RL      Reg    Inside      Edwards     1Story     Gable
# 156        RL      Reg    Inside        NAmes     1Story       Hip
# 90         RL      Reg    Inside        NAmes     1Story     Gable
# 1216       RM      Reg    Inside       Sawyer     1.5Fin     Gable
# 1048       RL      Reg    Inside      Mitchel     1Story       Hip
# 894        RL      Reg    Inside      SawyerW     1Story     Gable
# 102        RL      Reg    Inside      SawyerW     1Story     Gable
# 182        RL      Reg    Inside      Edwards     1Story       Hip
# 984        RL      Reg    Inside      Mitchel     1.5Fin     Gable
# 371        RL      Reg    Inside      ClearCr     1.5Fin     Gable
# 1045       RL      IR1   CulDSac      Edwards     1Story       Hip
# 897        RL      Reg    Inside      SawyerW     2Story     Gable
# 778        RH      Reg    Inside      SawyerW     1Story     Gable
# 868        RL      IR2    Corner      Gilbert     2Story     Gable
# 362        RL      Reg    Corner      Edwards     SFoyer     Gable
#
#      Exterior1st Exterior2nd MasVnrType ExterQual Foundation BsmtQual  \
# 533      VinylSd     VinylSd       None        Fa       Slab      NaN
# 705      VinylSd     Wd Shng       None        Fa       Slab      NaN
# 1321     VinylSd     VinylSd       None        TA     CBlock      NaN
# 1218     AsbShng     AsbShng       None        TA       Slab      NaN
# 39       AsbShng     Plywood       None        TA      PConc      NaN
# 1000     BrkComm     Brk Cmn       None        TA       Slab      NaN
# 1035     Wd Sdng     Wd Sdng       None        TA       Slab      NaN
# 1049     MetalSd     MetalSd       None        TA     CBlock      NaN
# 342       Stucco      Stucco    BrkFace        TA       Slab      NaN
# 17       MetalSd     MetalSd       None        TA       Slab      NaN
# 1412     BrkFace       Stone       None        TA       Slab      NaN
# 1090     BrkFace     BrkFace       None        TA       Slab      NaN
# 1179     Wd Sdng     Wd Sdng       None        TA       Slab      NaN
# 736       Stucco       Stone       None        TA     CBlock      NaN
# 259      BrkFace     BrkFace       None        TA      PConc      NaN
# 749      WdShing     Wd Shng       None        TA       Slab      NaN
# 646      MetalSd     MetalSd       None        TA     CBlock      NaN
# 1011     AsphShn     AsphShn       None        TA     CBlock      NaN
# 1232     HdBoard     HdBoard       None        TA       Slab      NaN
# 520      MetalSd     MetalSd       None        TA     BrkTil      NaN
# 392      MetalSd     MetalSd       None        TA       Slab      NaN
# 532      VinylSd     VinylSd       None        TA       Slab      NaN
# 553      VinylSd     VinylSd       None        TA     CBlock      NaN
# 156      Wd Sdng     Wd Sdng       None        TA     CBlock      NaN
# 90       BrkFace     Wd Sdng       None        TA       Slab      NaN
# 1216     VinylSd     VinylSd       None        TA       Slab      NaN
# 1048     HdBoard     HdBoard    BrkFace        TA       Slab      NaN
# 894      Plywood     Plywood       None        TA       Slab      NaN
# 102      HdBoard     HdBoard       None        TA       Slab      NaN
# 182      Wd Sdng     Wd Sdng    BrkFace        TA      PConc      NaN
# 984      Plywood     Plywood       None        TA     CBlock      NaN
# 371      WdShing     Plywood       None        TA     CBlock      NaN
# 1045     BrkFace     Wd Sdng       None        TA       Slab      NaN
# 897      Plywood     Plywood       None        TA       Slab      NaN
# 778      Plywood     Plywood    BrkFace        TA       Slab      NaN
# 868      Plywood     Plywood       None        TA       Slab      NaN
# 362      HdBoard     HdBoard    BrkFace        Gd       Slab      NaN
#
#      BsmtExposure BsmtFinType1 HeatingQC KitchenQual GarageType GarageFinish  \
# 533            No          NaN        Fa          Fa     Attchd          Unf
# 705            No          NaN        Fa          Fa     Attchd          Unf
# 1321           No          NaN        TA          TA     Detchd          Unf
# 1218           No          NaN        Gd          TA     Attchd          Unf
# 39             No          NaN        TA          Fa     Attchd          Unf
# 1000           No          NaN        Fa          Fa     Detchd          Unf
# 1035           No          NaN        Ex          TA     Detchd          Unf
# 1049           No          NaN        Ex          Gd     Detchd          Unf
# 342            No          NaN        Fa          TA     Detchd          Unf
# 17             No          NaN        TA          TA    CarPort          Unf
# 1412           No          NaN        Fa          TA     Detchd          Unf
# 1090           No          NaN        Fa          TA     Detchd          Unf
# 1179           No          NaN        Gd          TA     Attchd          Unf
# 736            No          NaN        Gd          TA     Detchd          Unf
# 259            No          NaN        Gd          TA     Detchd          Unf
# 749            No          NaN        TA          TA     Detchd          Unf
# 646            No          NaN        Gd          TA     Detchd          Unf
# 1011           No          NaN        TA          TA     Attchd          Unf
# 1232           No          NaN        TA          TA    CarPort          Unf
# 520            No          NaN        TA          TA     Attchd          Unf
# 392            No          NaN        TA          TA     Attchd          RFn
# 532            No          NaN        Ex          TA     Detchd          Unf
# 553            No          NaN        Ex          Gd     Detchd          Fin
# 156            No          NaN        TA          TA     Detchd          Unf
# 90             No          NaN        TA          TA     Detchd          Unf
# 1216           No          NaN        TA          TA     Attchd          Unf
# 1048           No          NaN        TA          TA     Attchd          Unf
# 894            No          NaN        TA          TA     Attchd          Unf
# 102            No          NaN        TA          TA     Attchd          Unf
# 182            No          NaN        Ex          TA     Attchd          RFn
# 984            No          NaN        TA          Gd     Attchd          Unf
# 371            No          NaN        TA          TA     Detchd          Fin
# 1045           No          NaN        Ex          TA     Attchd          Unf
# 897            No          NaN        TA          TA     Detchd          Unf
# 778            No          NaN        TA          TA     Detchd          Unf
# 868            No          NaN        Gd          TA     Attchd          Unf
# 362            No          NaN        Ex          Gd    BuiltIn          RFn
#
#       SalePrice
# 533       39300
# 705       55000
# 1321      72500
# 1218      80500
# 39        82000
# 1000      82000
# 1035      84000
# 1049      84900
# 342       87500
# 17        90000
# 1412      90000
# 1090      92900
# 1179      93000
# 736       93500
# 259       97000
# 749       98000
# 646       98300
# 1011     100000
# 1232     101800
# 520      106250
# 392      106500
# 532      107500
# 553      108000
# 156      109500
# 90       109900
# 1216     112000
# 1048     115000
# 894      118858
# 102      118964
# 182      120000
# 984      126000
# 371      134432
# 1045     139600
# 897      142953
# 778      144000
# 868      169000
# 362      198500

# %%
cate_sales['BsmtFinType1'].loc[(cate_sales['BsmtFinType1'].isna())&(cate_sales['SalePrice']<95000)]='Unf'
cate_sales['BsmtFinType1'].loc[(cate_sales['BsmtFinType1'].isna()) & (cate_sales['SalePrice']>95000)]='GLQ'
cate['BsmtFinType1'].loc[(cate['BsmtFinType1'].isna()) & (cate['SalePrice']<95000)]='Unf'
cate['BsmtFinType1'].loc[(cate['BsmtFinType1'].isna()) & (cate['SalePrice']>95000)]='GLQ'
df['BsmtFinType1'].loc[(df['BsmtFinType1'].isna()) & (df['SalePrice']<95000)]='Unf'
df['BsmtFinType1'].loc[(df['BsmtFinType1'].isna()) & (df['SalePrice']>95000)]='GLQ'
# Out:
# C:\Users\oukle\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\oukle\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\oukle\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\oukle\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\oukle\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\oukle\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\oukle\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\oukle\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\oukle\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\oukle\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
cate_sales['BsmtQual'].loc[(cate_sales['BsmtQual'].isna())&(cate_sales['SalePrice']<95000)]='TA'
cate_sales['BsmtQual'].loc[(cate_sales['BsmtQual'].isna()) & (cate_sales['SalePrice']>95000)]='Gd'
cate['BsmtQual'].loc[(cate['BsmtQual'].isna()) & (cate['SalePrice']<95000)]='TA'
cate['BsmtQual'].loc[(cate['BsmtQual'].isna()) & (cate['SalePrice']>95000)]='Gd'
df['BsmtQual'].loc[(df['BsmtQual'].isna()) & (df['SalePrice']<95000)]='TA'
df['BsmtQual'].loc[(df['BsmtQual'].isna()) & (df['SalePrice']>95000)]='Gd'
# Out:
# C:\Users\oukle\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\oukle\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\oukle\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\oukle\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\oukle\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\oukle\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\oukle\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\oukle\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\oukle\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\oukle\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
#preview with encoding labels
from sklearn.preprocessing import LabelEncoder

LE=LabelEncoder()
cate_labels=cate.iloc[:,:-1].apply(LE.fit_transform)

# %%
cate_labels['SalePrice']=df['SalePrice']

# %%
abs(cate_labels.corr()['SalePrice']).sort_values()
# Out:
# MasVnrType      0.018216
# LotConfig       0.067396
# BsmtFinType1    0.073439
# Exterior1st     0.103551
# Exterior2nd     0.103766
# MSZoning        0.166872
# HouseStyle      0.180163
# Neighborhood    0.210851
# RoofStyle       0.222405
# LotShape        0.255580
# BsmtExposure    0.295407
# GarageType      0.302105
# Foundation      0.382479
# HeatingQC       0.400178
# GarageFinish    0.537242
# KitchenQual     0.589189
# BsmtQual        0.607186
# ExterQual       0.636884
# SalePrice       1.000000
# Name: SalePrice, dtype: float64

# %%
cate.drop(['MasVnrType'],axis=1,inplace=True)
cate_labels.drop(['MasVnrType'],axis=1,inplace=True)
df.drop(['MasVnrType'],axis=1,inplace=True)
df_test.drop(['MasVnrType'],axis=1,inplace=True)
# Out:
# C:\Users\oukle\Anaconda3\lib\site-packages\pandas\core\frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
cate
# Out:
#      MSZoning LotShape LotConfig Neighborhood HouseStyle RoofStyle  \
# 0          RL      Reg    Inside      CollgCr     2Story     Gable
# 1          RL      Reg       FR2      Veenker     1Story     Gable
# 2          RL      IR1    Inside      CollgCr     2Story     Gable
# 3          RL      IR1    Corner      Crawfor     2Story     Gable
# 4          RL      IR1       FR2      NoRidge     2Story     Gable
# ...       ...      ...       ...          ...        ...       ...
# 1455       RL      Reg    Inside      Gilbert     2Story     Gable
# 1456       RL      Reg    Inside       NWAmes     1Story     Gable
# 1457       RL      Reg    Inside      Crawfor     2Story     Gable
# 1458       RL      Reg    Inside        NAmes     1Story       Hip
# 1459       RL      Reg    Inside      Edwards     1Story     Gable
#
#      Exterior1st Exterior2nd ExterQual Foundation BsmtQual BsmtExposure  \
# 0        VinylSd     VinylSd        Gd      PConc       Gd           No
# 1        MetalSd     MetalSd        TA     CBlock       Gd           Gd
# 2        VinylSd     VinylSd        Gd      PConc       Gd           Mn
# 3        Wd Sdng     Wd Shng        TA     BrkTil       TA           No
# 4        VinylSd     VinylSd        Gd      PConc       Gd           Av
# ...          ...         ...       ...        ...      ...          ...
# 1455     VinylSd     VinylSd        TA      PConc       Gd           No
# 1456     Plywood     Plywood        TA     CBlock       Gd           No
# 1457     CemntBd     CmentBd        Ex      Stone       TA           No
# 1458     MetalSd     MetalSd        TA     CBlock       TA           Mn
# 1459     HdBoard     HdBoard        Gd     CBlock       TA           No
#
#      BsmtFinType1 HeatingQC KitchenQual GarageType GarageFinish  SalePrice
# 0             GLQ        Ex          Gd     Attchd          RFn     208500
# 1             ALQ        Ex          TA     Attchd          RFn     181500
# 2             GLQ        Ex          Gd     Attchd          RFn     223500
# 3             ALQ        Gd          Gd     Detchd          Unf     140000
# 4             GLQ        Ex          Gd     Attchd          RFn     250000
# ...           ...       ...         ...        ...          ...        ...
# 1455          Unf        Ex          TA     Attchd          RFn     175000
# 1456          ALQ        TA          TA     Attchd          Unf     210000
# 1457          GLQ        Ex          Gd     Attchd          RFn     266500
# 1458          GLQ        Gd          Gd     Attchd          Unf     142125
# 1459          BLQ        Gd          TA     Attchd          Fin     147500
#
# [1460 rows x 18 columns]

# %%
cate_corr=cate_labels.corr()

# %%
plt.figure(figsize=(30,18))
sns.heatmap(cate_corr,annot=True,cmap='coolwarm')

# %%
#It looks good to go next.

# %%
#Overall correlation

# %%
nume=nume.reset_index()

# %%
overall=pd.concat([nume,cate_labels],axis=1)

# %%
overall=overall.set_index('Id')

# %%
over_corr=overall.corr()

# %%
plt.figure(figsize=(30,18))
sns.heatmap(over_corr,annot=True,cmap='coolwarm')

# %% [markdown]
# ### Testset fillna

# %%
df_test.isna().sum().sort_values()
# Out:
# Id                 0
# ScreenPorch        0
# HeatingQC          0
# 1stFlrSF           0
# 2ndFlrSF           0
# GrLivArea          0
# FullBath           0
# Foundation         0
# HalfBath           0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# BedroomAbvGr       0
# ExterQual          0
# PoolArea           0
# Neighborhood       0
# MSSubClass         0
# LotArea            0
# LotShape           0
# RoofStyle          0
# YearRemodAdd       0
# YearBuilt          0
# OverallCond        0
# LotConfig          0
# OverallQual        0
# HouseStyle         0
# GarageArea         1
# GarageCars         1
# KitchenQual        1
# Exterior2nd        1
# TotalBsmtSF        1
# Exterior1st        1
# BsmtFinSF1         1
# BsmtUnfSF          1
# BsmtFullBath       2
# MSZoning           4
# MasVnrArea        15
# BsmtFinType1      42
# BsmtExposure      44
# BsmtQual          44
# GarageType        76
# GarageYrBlt       78
# GarageFinish      78
# LotFrontage      227
# dtype: int64

# %%
df_test.GarageYrBlt.fillna(df_test.YearBuilt,inplace=True)

# %%
df_test.GarageFinish.value_counts()
# Out:
# Unf    625
# RFn    389
# Fin    367
# Name: GarageFinish, dtype: int64

# %%
df_test.GarageFinish.fillna(df_test.GarageFinish.mode()[0],inplace=True)

# %%
df_test.GarageType.value_counts()
# Out:
# Attchd     853
# Detchd     392
# BuiltIn     98
# Basment     17
# 2Types      17
# CarPort      6
# Name: GarageType, dtype: int64

# %%
df_test.GarageType.fillna(df_test.GarageType.mode()[0],inplace=True)

# %%
df_test.BsmtExposure.value_counts()
# Out:
# No    951
# Av    197
# Gd    142
# Mn    125
# Name: BsmtExposure, dtype: int64

# %%
df_test.BsmtExposure.fillna(df_test.BsmtExposure.mode()[0],inplace=True)

# %%
df_test.MasVnrArea.value_counts()[0]/len(df_test)
df_test.MasVnrArea.fillna(df_test.MasVnrArea.mode()[0],inplace=True)

# %%
df_test.BsmtQual.value_counts()
# Out:
# TA    634
# Gd    591
# Ex    137
# Fa     53
# Name: BsmtQual, dtype: int64

# %%
df_test.BsmtQual.fillna(df_test.ExterQual,inplace=True)

# %%
df_test.BsmtFinType1.value_counts() 
# hardest part for data preprocessing here. I put the most frequent one since it does not have much correlation to the saleprice.
# Out:
# GLQ    431
# Unf    421
# ALQ    209
# Rec    155
# BLQ    121
# LwQ     80
# Name: BsmtFinType1, dtype: int64

# %%
df_test_nan=df_test.loc[df_test.BsmtFinType1.isna()]
df_test_nan[['BsmtQual','BsmtExposure','BsmtFullBath']]
# Out:
#      BsmtQual BsmtExposure  BsmtFullBath
# 125        TA           No           0.0
# 133        TA           No           0.0
# 269        TA           No           0.0
# 318        TA           No           0.0
# 354        TA           No           0.0
# 387        TA           No           0.0
# 388        TA           No           0.0
# 396        Gd           No           0.0
# 397        TA           No           0.0
# 398        TA           No           0.0
# 400        TA           No           0.0
# 455        Fa           No           0.0
# 590        TA           No           0.0
# 606        TA           No           0.0
# 608        TA           No           0.0
# 660        TA           No           NaN
# 662        TA           No           0.0
# 728        TA           No           NaN
# 729        TA           No           0.0
# 730        TA           No           0.0
# 733        TA           No           0.0
# 756        Fa           No           0.0
# 764        TA           No           0.0
# 927        TA           No           0.0
# 975        TA           No           0.0
# 992        TA           No           0.0
# 993        TA           No           0.0
# 1030       Fa           No           0.0
# 1038       TA           No           0.0
# 1087       TA           No           0.0
# 1092       TA           No           0.0
# 1104       TA           No           0.0
# 1118       TA           No           0.0
# 1139       TA           No           0.0
# 1242       TA           No           0.0
# 1303       TA           No           0.0
# 1306       TA           No           0.0
# 1343       TA           No           0.0
# 1344       TA           No           0.0
# 1364       TA           No           0.0
# 1431       TA           No           0.0
# 1444       TA           No           0.0

# %%
df_test.BsmtFinType1.fillna('Unf',inplace=True)

# %%
df_test.isna().sum().sort_values()
# Out:
# Id                 0
# ScreenPorch        0
# HeatingQC          0
# 1stFlrSF           0
# 2ndFlrSF           0
# GrLivArea          0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageType         0
# GarageYrBlt        0
# GarageFinish       0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# BsmtFinType1       0
# BsmtExposure       0
# PoolArea           0
# Foundation         0
# MSSubClass         0
# LotArea            0
# LotShape           0
# LotConfig          0
# Neighborhood       0
# HouseStyle         0
# BsmtQual           0
# OverallCond        0
# YearBuilt          0
# OverallQual        0
# RoofStyle          0
# MasVnrArea         0
# ExterQual          0
# YearRemodAdd       0
# KitchenQual        1
# Exterior1st        1
# Exterior2nd        1
# TotalBsmtSF        1
# GarageCars         1
# GarageArea         1
# BsmtFinSF1         1
# BsmtUnfSF          1
# BsmtFullBath       2
# MSZoning           4
# LotFrontage      227
# dtype: int64

# %%
df_test.BsmtFullBath.fillna(df_test.BsmtFullBath.mode()[0],inplace=True) # handling with columns with 1 or 2 Nan.-> fill the most frequent value in the nan
df_test.BsmtUnfSF.fillna(df_test.BsmtUnfSF.mode()[0],inplace=True)
df_test.BsmtFinSF1.fillna(df_test.BsmtFinSF1.mode()[0],inplace=True)
df_test.GarageCars.fillna(df_test.GarageCars.mode()[0],inplace=True)
df_test.GarageArea.fillna(df_test.GarageArea.mode()[0],inplace=True)
df_test.TotalBsmtSF.fillna(df_test.TotalBsmtSF.mode()[0],inplace=True)
df_test.Exterior1st.fillna(df_test.Exterior1st.mode()[0],inplace=True)
df_test.Exterior2nd.fillna(df_test.Exterior2nd.mode()[0],inplace=True)
df_test.KitchenQual.fillna(df_test.KitchenQual.mode()[0],inplace=True)
df_test.MSZoning.fillna(df_test.MSZoning.mode()[0],inplace=True)

# %%
df_test['LotFrontage'].fillna(df_test['LotFrontage'].median(),inplace=True)

# %%
df_test.isna().sum().sort_values()
# Out:
# Id               0
# HeatingQC        0
# 1stFlrSF         0
# 2ndFlrSF         0
# GrLivArea        0
# BsmtFullBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotalBsmtSF      0
# KitchenQual      0
# Fireplaces       0
# GarageType       0
# GarageYrBlt      0
# GarageFinish     0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# TotRmsAbvGrd     0
# ScreenPorch      0
# BsmtUnfSF        0
# BsmtFinType1     0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# LotShape         0
# LotConfig        0
# Neighborhood     0
# HouseStyle       0
# OverallQual      0
# BsmtFinSF1       0
# OverallCond      0
# YearRemodAdd     0
# RoofStyle        0
# Exterior1st      0
# Exterior2nd      0
# MasVnrArea       0
# ExterQual        0
# Foundation       0
# BsmtQual         0
# BsmtExposure     0
# YearBuilt        0
# PoolArea         0
# dtype: int64

# %% [markdown]
# ### get_dummies

# %%
df=df.reset_index(drop=True)

# %%
df=df.set_index('Id')
df_test=df_test.set_index('Id')

# %%
df_train=df.iloc[:,:-1]
df_y=df.iloc[:,-1]
df_all=pd.concat([df_train,df_test])

# %%
df_all=pd.get_dummies(df_all)

# %%
df_train=df_all.iloc[:1460,:]
df_test=df_all.iloc[1460:,:]

# %%
df_train=pd.concat([df_train,df_y],axis=1)

# %% [markdown]
# ## Train and validation dataset

# %%
from sklearn.model_selection import RepeatedKFold,KFold, cross_validate, cross_val_score

rkf = RepeatedKFold(n_splits=10, n_repeats=5,random_state=42)
X_train_full, y_train_full= df_train.iloc[:,:-1],df_train['SalePrice']

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
X_train,X_val,y_train,y_val=train_test_split(df_train.iloc[:,:-1],df_train['SalePrice'],test_size=0.1,random_state=42,shuffle=True)

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()

# %% [markdown]
# ## Training

# %% [markdown]
# ### Linear

# %%
linear=make_pipeline(sc,LinearRegression())

# %%
linear.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('minmaxscaler', MinMaxScaler(copy=True, feature_range=(0, 1))),
#                 ('linearregression',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
y_pred=linear.predict(X_val)

# %%
y_pred
# Out:
# array([148900., 345404., 101164., 195708., 327988.,  54692., 247636.,
#        150636.,  58636., 143412., 140168., 112332.,  71908., 236500.,
#        177212., 133084., 191908., 128444., 130592., 212868., 170812.,
#        208948., 181768., 136456., 208660., 149516., 197856.,  99980.,
#        169308., 210764., 133156., 280240., 262108., 104916., 247204.,
#        141996., 142724., 208592., 328340., 111072., 140276., 225188.,
#        103636., 346804., 124668., 138924., 101388., 129028., 401676.,
#        133508., 119028., 254524.,  92860., 303860., 167536., 227224.,
#        202924., 187860., 136964., 119836.,  84956., 163252., 332284.,
#        248028., 294612., 193828.,  89668., 293776., 104676., 166256.,
#        135076., 123556., 101240.,  26772., 417328., 157452., 301888.,
#        377196., 152652., 130948., 111104.,  83292., 109692.,  98116.,
#        157888., 130692., 251724., 193316., 142844., 185488., 138612.,
#        164572., 187628., 258312., 109980., 186672., 208612., 155980.,
#        194348., 263972., 125244., 209836., 249088., 145884., 194628.,
#        194388., 152128., 280076., 146732., 198404.,  57740., 116444.,
#        138452., 140948., 205788., 124996.,  97356., 117404., 148604.,
#        281756., 127760., 144396., 181060., 191404., 176556., 132820.,
#        229176., 108292., 148020., 191404., 188812., 313500., 200956.,
#        125172.,  39244., 382856., 337460., 146556., 215148., 511556.,
#        343960., 126332., 172080., 161956., 124092., 113780.])

# %%
y_val
# Out:
# Id
# 893     154500
# 1106    325000
# 414     115000
# 523     159000
# 1037    315500
#          ...
# 527     132000
# 102     178000
# 1093    136500
# 412     145000
# 1393    123000
# Name: SalePrice, Length: 146, dtype: int64

# %%
linear.score(X_val,y_val)
# Out:
# 0.8647342380924282

# %%
linear.score(X_train,y_train)
# Out:
# 0.8848777803087421

# %%
scores_linear=cross_validate(linear,X_train_full,y_train_full,cv=rkf,scoring='r2')
scores_linear['test_score'].mean()
# Out:
# -5.14207223778728e+21

# %%
scores_linear=cross_validate(linear,X_train,y_train,cv=rkf,scoring='r2')
scores_linear['test_score'].mean()
# Out:
# -2.396239263684547e+22

# %%
scores_linear
# Out:
# {'fit_time': array([0.0120101 , 0.01101041, 0.01301146, 0.01200938, 0.01100922,
#         0.01000834, 0.01100945, 0.01201034, 0.01100898, 0.01100993,
#         0.01100945, 0.01100993, 0.01000953, 0.01100945, 0.01201177,
#         0.01301003, 0.01101041, 0.01201105, 0.01301122, 0.01100874,
#         0.01100826, 0.01201057, 0.01200986, 0.01101065, 0.0110085 ,
#         0.01200986, 0.01000953, 0.01000619, 0.01000905, 0.0110085 ,
#         0.01100993, 0.01201129, 0.01200962, 0.01201081, 0.01000786,
#         0.01200962, 0.01200962, 0.0120101 , 0.01100993, 0.01200914,
#         0.01100969, 0.01000929, 0.01000857, 0.01100945, 0.01100993,
#         0.01000881, 0.01100922, 0.01101041, 0.01100874, 0.01201129]),
#  'score_time': array([0.00100088, 0.00200105, 0.00100112, 0.00100088, 0.00100136,
#         0.00100088, 0.00200176, 0.00100112, 0.0010004 , 0.00100112,
#         0.00100112, 0.00100017, 0.0010004 , 0.00100088, 0.00099969,
#         0.00100064, 0.00200152, 0.00099993, 0.00100136, 0.00100112,
#         0.00100088, 0.00100112, 0.00100064, 0.00200129, 0.00100088,
#         0.00100112, 0.00100088, 0.00100136, 0.00100064, 0.00100064,
#         0.0010004 , 0.00100088, 0.00100088, 0.00100112, 0.00200224,
#         0.00100088, 0.00100088, 0.00100112, 0.00100088, 0.00100112,
#         0.00100183, 0.00100088, 0.00100064, 0.00100064, 0.        ,
#         0.00100064, 0.00100112, 0.00100112, 0.00100112, 0.00100017]),
#  'test_score': array([ 8.56178507e-01, -2.68967265e+20,  8.40971990e-01, -1.31059682e+18,
#          8.97082846e-01, -1.33784777e+17, -1.37454191e+17, -3.95143277e+20,
#         -9.68755619e+12, -4.97234426e+18,  8.75446414e-01, -7.01794272e+19,
#          9.12474147e-01,  8.87012546e-01,  8.23418180e-01,  3.50489374e-01,
#         -2.93352191e+18, -4.46602820e+17, -1.97979506e+17,  8.88771562e-01,
#          8.87050088e-01,  4.50307084e-01, -1.56557178e+19,  7.37120660e-01,
#          8.92278242e-01, -1.19134634e+15,  9.01871062e-01,  8.06085649e-01,
#         -8.51906378e+12,  8.53612554e-01,  8.47200595e-01, -2.49180674e+22,
#         -1.47521488e+18, -1.17227904e+24, -4.20888097e+18,  8.78201432e-01,
#          8.88170999e-01,  7.66217872e-01, -1.41570650e+14, -6.88548238e+19,
#          8.28290549e-01,  8.49011526e-01,  7.46270743e-01,  8.81889328e-01,
#         -6.23914495e+19, -2.54354665e+19, -8.36160248e+16,  8.68847730e-01,
#          8.67262650e-01,  4.44921545e-01])}

# %%
cross_val=cross_val_score(linear,X_train_full,y_train_full,cv=10,scoring='r2')
cross_val.mean()
# Out:
# -5.731478735580942e+22

# %%
y_test_pred_linear=linear.predict(df_test)

# %%
y_test_pred_linear
# Out:
# array([123180., 151804., 171148., ..., 160748.,  88612., 214080.])

# %% [markdown]
# ### Elastic Net

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import ElasticNet
EN=make_pipeline(sc,ElasticNet())
parametersGrid = {"elasticnet__max_iter": [1, 5, 10,100,1000],
                      "elasticnet__alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100],
                      "elasticnet__l1_ratio": np.arange(0.0, 1.0, 0.1)}
grid = GridSearchCV(EN, parametersGrid,scoring='r2', cv=10)
grid.fit(X_train,y_train)
Y_pred = grid.predict(X_val)
# Out:
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 925418921804.5721, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 955442053251.3966, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 857549651273.0151, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 911153850677.5455, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 873845438242.2491, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 880605782525.8917, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 957615892217.3507, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 964350246127.8815, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 930725931097.0537, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 941291769225.978, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 520331108111.5806, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 529370282938.3541, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 479403247740.7326, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 488476950701.18066, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 443405575470.67694, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 484584771397.3916, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 526526696463.413, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 531530002808.02075, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 528195496465.6187, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 532434778120.34595, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 457239109145.44946, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 465557408552.2801, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 421662877797.9409, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 426743633328.6537, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 381152460515.04065, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 424772510733.09015, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 466655060573.15027, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 467835429289.18274, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 467701427159.0256, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 469028639463.42194, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 417406306199.1886, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 422975108541.9945, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 382406192582.13074, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 386992496286.5671, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 335694061533.0318, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 381790313652.3606, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 424684181010.37256, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 423806299250.9516, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 424050530486.41437, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 427456612621.0434, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 417318140574.33777, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 422870314143.72705, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 382301653607.2373, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 386897864773.5422, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 335561332998.57623, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 381715032309.6486, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 424587062864.9065, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 423690130745.704, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 423922753965.7077, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 427362452387.09766, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 924368679745.0818, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 954387113951.8054, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 856501608134.91, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 910092256445.7952, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 872849532651.177, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 879618650614.6606, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 956555156738.1669, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 963328526457.0798, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 929645207107.8502, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 940210623187.906, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 519936636223.6405, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 528985557007.05524, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 479026650616.964, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 488058986935.5154, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 443024781612.9108, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 484175473238.81854, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 526101020533.83777, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 531184158284.5267, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 527815320421.73206, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 532026937687.93567, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 456796145462.0325, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 465119117316.66785, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 421266253405.8291, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 426270852976.9974, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 380706020584.0497, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 424320834715.5074, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 466191108166.29144, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 467430515232.51624, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 467286927219.7313, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 468580997654.64105, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 417022917750.9035, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 422587752088.277, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 382053879737.1737, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 386548718291.9804, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 335313936106.6746, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 381392648436.0086, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 424262833852.779, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 423438229624.24866, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 423661239564.2648, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 427049659147.2262, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 416922432753.6509, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 422473877617.1801, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 381943111978.87714, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 386439168061.3491, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 335164039682.54, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 381308813031.7679, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 424153670856.7007, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 423319071365.79694, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 423524380505.07983, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 426941332402.05566, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 923312606034.9901, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 953326660279.4254, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 855448081645.1478, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 909024986609.8251, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 871847624545.7104, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 878625694819.5677, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 955488174746.4022, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 962301337598.2963, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 928558815242.6866, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 939123273163.4834, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 519538381691.5797, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 528597568422.85876, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 478647046750.2923, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 487637298980.4381, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 442641198815.26154, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 483761928422.4949, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 525670880351.0324, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 530835580786.1289, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 527432047827.93744, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 531615299158.242, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 456349207777.7012, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 464677163045.85986, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 420866473618.24915, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 425794206787.78503, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 380256441268.95435, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 423864202847.66, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 465722538438.9467, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 467022514751.9399, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 466869326137.98663, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 468129391747.7837, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 416635425578.0356, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 422195329159.5344, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 381697739247.0692, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 386098788146.41455, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 334930795110.52496, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 380992008104.6719, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 423835384896.7123, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 423064579411.4261, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 423265070361.19366, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 426637373663.4801, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 416520464592.59674, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 422070207611.07056, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 381580752595.64935, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 385971237163.28357, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 334761991903.8889, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 380899499131.5565, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 423712859958.049, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 422942069090.83606, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 423119172731.4863, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 426512822811.6682, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 922250596033.1248, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 952260595193.1365, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 854388984663.7289, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 907951945277.7498, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 870839593640.4586, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 877626801915.35, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 954414848894.2727, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 961268577933.2778, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 927466657493.7534, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 938029609084.9241, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 519136207595.6526, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 528206201403.8135, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 478264343666.373, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 487211758458.41565, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 442254727590.75635, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 483343979176.3644, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 525236123674.2724, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 530484152515.3255, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 527045567365.9019, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 531199725122.5765, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 455898174363.0817, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 464231440985.16595, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 420463454789.53076, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 425313595157.92365, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 379803645416.84015, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 423402437466.20166, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 465249213417.74457, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 466611331499.0746, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 466448537971.4975, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 467673699874.93066, tolerance: 711690129.1104344
#   positive)
# ...
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2887879092698.8784, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2659609568740.7065, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2822362757633.0957, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2863561575869.122, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2653670804351.6543, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2818967666649.422, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2883398572396.6367, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2876513638340.151, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2820739384367.3447, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2729592409034.652, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2845003175811.7217, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2618040958431.6963, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2779978401518.829, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2820312421541.2285, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2612832421025.3403, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2776358378759.515, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2840432912637.072, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2833250396240.452, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2778226634955.6963, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2740786985347.0713, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2855475003364.751, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2629204564626.386, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2790911266057.7324, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2831067417660.477, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2623313656198.2256, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2787282882455.954, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2850506833475.7856, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2844168139291.9194, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2789019923902.534, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2800335497441.159, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2913787915421.742, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2687915639567.48, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2849825899650.877, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2890299923752.839, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2679937034098.129, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2846366963584.4893, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2908002766347.2637, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2903786374030.6426, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2847735528509.6465, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2892850817977.548, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3003978127564.375, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2779106273709.4014, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2941232847344.8345, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2981971191050.9624, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2767676755122.8564, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2938011208888.329, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2996653437936.1797, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2996202833398.6504, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2938751930499.1514, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2956247524227.9316, tolerance: 702235494.6783398
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3061366176055.931, tolerance: 725894087.6557243
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2842024335976.508, tolerance: 676921220.0183051
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3002478466076.82, tolerance: 711808318.2706782
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3041082428373.4136, tolerance: 722507929.5029123
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2825877155265.2344, tolerance: 672599230.3114893
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2999151790587.2354, tolerance: 711792939.9706756
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3050495454091.053, tolerance: 724791841.4249041
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3057081251921.2495, tolerance: 725342319.8812188
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2998906530169.0425, tolerance: 711690129.1104344
#   positive)
# C:\Users\oukle\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 615852651557.8726, tolerance: 787334624.1028306
#   positive)

# %%
grid.best_params_
# Out:
# {'elasticnet__alpha': 0.01,
#  'elasticnet__l1_ratio': 0.2,
#  'elasticnet__max_iter': 100}

# %%
EN.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('minmaxscaler', MinMaxScaler(copy=True, feature_range=(0, 1))),
#                 ('elasticnet',
#                  ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True,
#                             l1_ratio=0.5, max_iter=1000, normalize=False,
#                             positive=False, precompute=False, random_state=None,
#                             selection='cyclic', tol=0.0001,
#                             warm_start=False))],
#          verbose=False)

# %%
y_pred_EN=EN.predict(X_val)

# %%
EN.score(X_val,y_val)
# Out:
# 0.5814765582218164

# %%
EN.score(X_train,y_train)
# Out:
# 0.6274143085888728

# %%
scores_EN=cross_validate(EN,X_train_full,y_train_full,cv=rkf,scoring=['r2','neg_mean_squared_log_error'])
scores_EN['test_r2'].mean()
# Out:
# 0.6274556360121566

# %% [markdown]
# ### Random forest

# %%
from sklearn.ensemble import RandomForestRegressor
Rf=make_pipeline(sc,RandomForestRegressor())

parametersGrid = {
 'randomforestregressor__max_depth': [10, 20, 30, 40],
 'randomforestregressor__min_samples_split': [2, 5],
 'randomforestregressor__n_estimators': [200, 600, 1000]}
grid = GridSearchCV(estimator=Rf, param_grid=parametersGrid,scoring='r2', cv=10)
grid.fit(X_train_full,y_train_full)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('minmaxscaler',
#                                         MinMaxScaler(copy=True,
#                                                      feature_range=(0, 1))),
#                                        ('randomforestregressor',
#                                         RandomForestRegressor(bootstrap=True,
#                                                               ccp_alpha=0.0,
#                                                               criterion='mse',
#                                                               max_depth=None,
#                                                               max_features='auto',
#                                                               max_leaf_nodes=None,
#                                                               max_samples=None,
#                                                               min_impurity_decrease=0.0,
#                                                               min_impurity_split=None,
#                                                               mi...
#                                                               oob_score=False,
#                                                               random_state=None,
#                                                               verbose=0,
#                                                               warm_start=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'randomforestregressor__max_depth': [10, 20, 30, 40],
#                          'randomforestregressor__min_samples_split': [2, 5],
#                          'randomforestregressor__n_estimators': [200, 600,
#                                                                  1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='r2', verbose=0)

# %%
grid.best_params_
# Out:
# {'randomforestregressor__max_depth': 30,
#  'randomforestregressor__min_samples_split': 2,
#  'randomforestregressor__n_estimators': 600}

# %%
Rf.set_params(**grid.best_params_)
Rf.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('minmaxscaler', MinMaxScaler(copy=True, feature_range=(0, 1))),
#                 ('randomforestregressor',
#                  RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                        criterion='mse', max_depth=30,
#                                        max_features='auto', max_leaf_nodes=None,
#                                        max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_impurity_split=None,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators=600, n_jobs=None,
#                                        oob_score=False, random_state=None,
#                                        verbose=0, warm_start=False))],
#          verbose=False)

# %%
y_val_pred_rf=Rf.predict(X_val)

# %%
Rf.score(X_val,y_val)
# Out:
# 0.9016295733674897

# %%
Rf.score(X_train,y_train)
# Out:
# 0.9804365019574846

# %%
scores_Rf=cross_validate(Rf,X_train_full,y_train_full,cv=rkf,scoring=['r2','neg_mean_squared_log_error'])
scores_Rf['test_r2'].mean()
# Out:
# 0.8631973355180957

# %%
scores_Rf['test_r2']
# Out:
# array([0.90417555, 0.87089846, 0.9342288 , 0.88531862, 0.67062415,
#        0.7960378 , 0.86608953, 0.87203907, 0.86596977, 0.9111684 ,
#        0.91052566, 0.90117562, 0.84193972, 0.89239234, 0.92219887,
#        0.86092355, 0.90181911, 0.79398604, 0.88929099, 0.69792853,
#        0.90774072, 0.81310398, 0.88801468, 0.88791828, 0.86750641,
#        0.87316408, 0.91630038, 0.84096528, 0.90253536, 0.83162506,
#        0.83706541, 0.87164717, 0.77186954, 0.81644482, 0.91019046,
#        0.77937074, 0.89134067, 0.91015269, 0.90085171, 0.87959902,
#        0.84871376, 0.89128832, 0.91685112, 0.74832275, 0.89977612,
#        0.89551147, 0.89559985, 0.86412698, 0.83501872, 0.87852066])

# %%
y_test_pred_Rf=Rf.predict(df_test)

# %%
y_test_pred_Rf
# Out:
# array([127063.94833333, 154346.78333333, 180221.81833333, ...,
#        156142.36333333, 120543.74333333, 225321.52333333])

# %% [markdown]
# ### LGBM

# %%
from lightgbm import LGBMRegressor

LGBM=make_pipeline(sc,LGBMRegressor())

# %%
LGBM.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'minmaxscaler', 'lgbmregressor', 'minmaxscaler__copy', 'minmaxscaler__feature_range', 'lgbmregressor__boosting_type', 'lgbmregressor__class_weight', 'lgbmregressor__colsample_bytree', 'lgbmregressor__importance_type', 'lgbmregressor__learning_rate', 'lgbmregressor__max_depth', 'lgbmregressor__min_child_samples', 'lgbmregressor__min_child_weight', 'lgbmregressor__min_split_gain', 'lgbmregressor__n_estimators', 'lgbmregressor__n_jobs', 'lgbmregressor__num_leaves', 'lgbmregressor__objective', 'lgbmregressor__random_state', 'lgbmregressor__reg_alpha', 'lgbmregressor__reg_lambda', 'lgbmregressor__silent', 'lgbmregressor__subsample', 'lgbmregressor__subsample_for_bin', 'lgbmregressor__subsample_freq'])

# %%
parametersGrid = {
    'lgbmregressor__num_leaves': [31, 127],
    'lgbmregressor__reg_alpha': [0.1, 0.5],
    'lgbmregressor__min_data_in_leaf': [30, 50, 100, 300, 400],
    'lgbmregressor__lambda_l1': [0, 1, 1.5],
    'lgbmregressor__lambda_l2': [0, 1]
    }
grid = GridSearchCV(estimator=LGBM, param_grid=parametersGrid,scoring='r2', cv=10)
grid.fit(X_train_full,y_train_full)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.5 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# ...
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=300, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=300
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.1 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=1.5, reg_alpha=0.5 will be ignored. Current value: lambda_l1=1.5
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# GridSearchCV(cv=10, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('minmaxscaler',
#                                         MinMaxScaler(copy=True,
#                                                      feature_range=(0, 1))),
#                                        ('lgbmregressor',
#                                         LGBMRegressor(boosting_type='gbdt',
#                                                       class_weight=None,
#                                                       colsample_bytree=1.0,
#                                                       importance_type='split',
#                                                       learning_rate=0.1,
#                                                       max_depth=-1,
#                                                       min_child_samples=20,
#                                                       min_child_weight=0.001,
#                                                       min_split_gain=0.0,
#                                                       n_estim...
#                                                       subsample_freq=0))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'lgbmregressor__lambda_l1': [0, 1, 1.5],
#                          'lgbmregressor__lambda_l2': [0, 1],
#                          'lgbmregressor__min_data_in_leaf': [30, 50, 100, 300,
#                                                              400],
#                          'lgbmregressor__num_leaves': [31, 127],
#                          'lgbmregressor__reg_alpha': [0.1, 0.5]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='r2', verbose=0)

# %%
LGBM.set_params(**grid.best_params_)
# Out:
# Pipeline(memory=None,
#          steps=[('minmaxscaler', MinMaxScaler(copy=True, feature_range=(0, 1))),
#                 ('lgbmregressor',
#                  LGBMRegressor(boosting_type='gbdt', class_weight=None,
#                                colsample_bytree=1.0, importance_type='split',
#                                lambda_l1=0, lambda_l2=1, learning_rate=0.1,
#                                max_depth=-1, min_child_samples=20,
#                                min_child_weight=0.001, min_data_in_leaf=30,
#                                min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                num_leaves=127, objective=None,
#                                random_state=None, reg_alpha=0.1, reg_lambda=0.0,
#                                silent=True, subsample=1.0,
#                                subsample_for_bin=200000, subsample_freq=0))],
#          verbose=False)

# %%
LGBM.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('minmaxscaler', MinMaxScaler(copy=True, feature_range=(0, 1))),
#                 ('lgbmregressor',
#                  LGBMRegressor(boosting_type='gbdt', class_weight=None,
#                                colsample_bytree=1.0, importance_type='split',
#                                lambda_l1=0, lambda_l2=1, learning_rate=0.1,
#                                max_depth=-1, min_child_samples=20,
#                                min_child_weight=0.001, min_data_in_leaf=30,
#                                min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                num_leaves=127, objective=None,
#                                random_state=None, reg_alpha=0.1, reg_lambda=0.0,
#                                silent=True, subsample=1.0,
#                                subsample_for_bin=200000, subsample_freq=0))],
#          verbose=False)

# %%
y_val_pred_lgbm=LGBM.predict(X_val)

# %%
LGBM.score(X_val,y_val)
# Out:
# 0.8824342723710883

# %%
LGBM.score(X_train,y_train)
# Out:
# 0.9654704548856192

# %%
scores_LGBM=cross_validate(LGBM,X_train,y_train,cv=rkf,scoring=['r2','neg_mean_squared_log_error'])
scores_LGBM['test_r2'].mean()
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# 0.8617505732674925

# %%
scores_LGBM['test_r2']
# Out:
# array([0.90041271, 0.88134677, 0.8438549 , 0.83314288, 0.91097269,
#        0.88299993, 0.87552561, 0.8462191 , 0.73710097, 0.91098209,
#        0.91219074, 0.92837501, 0.90787857, 0.92310324, 0.8767559 ,
#        0.74633153, 0.71849728, 0.78167226, 0.81901013, 0.89734952,
#        0.91758451, 0.76607226, 0.91234438, 0.7468957 , 0.93585475,
#        0.90873881, 0.91018791, 0.80664486, 0.86975698, 0.87763475,
#        0.88431627, 0.76526581, 0.87698896, 0.8834343 , 0.88048004,
#        0.9198602 , 0.94246667, 0.7611257 , 0.88113762, 0.88378033,
#        0.86291125, 0.83856986, 0.79752479, 0.90707305, 0.9088803 ,
#        0.85956249, 0.87024355, 0.87437788, 0.87378902, 0.83030378])

# %%
y_test_pred_lgbm=LGBM.predict(df_test)

# %%
y_test_pred_lgbm
# Out:
# array([126302.7630501 , 154716.68529205, 176814.26548207, ...,
#        169281.43162429, 121021.65917928, 205184.54415793])

# %% [markdown]
# ### XGB

# %%
from xgboost import XGBRegressor
#print(XGBRegressor.__version__)

# %%
xgb=make_pipeline(sc,XGBRegressor())

# %%
xgb.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'minmaxscaler', 'xgbregressor', 'minmaxscaler__copy', 'minmaxscaler__feature_range', 'xgbregressor__objective', 'xgbregressor__base_score', 'xgbregressor__booster', 'xgbregressor__colsample_bylevel', 'xgbregressor__colsample_bynode', 'xgbregressor__colsample_bytree', 'xgbregressor__gamma', 'xgbregressor__gpu_id', 'xgbregressor__importance_type', 'xgbregressor__interaction_constraints', 'xgbregressor__learning_rate', 'xgbregressor__max_delta_step', 'xgbregressor__max_depth', 'xgbregressor__min_child_weight', 'xgbregressor__missing', 'xgbregressor__monotone_constraints', 'xgbregressor__n_estimators', 'xgbregressor__n_jobs', 'xgbregressor__num_parallel_tree', 'xgbregressor__random_state', 'xgbregressor__reg_alpha', 'xgbregressor__reg_lambda', 'xgbregressor__scale_pos_weight', 'xgbregressor__subsample', 'xgbregressor__tree_method', 'xgbregressor__validate_parameters', 'xgbregressor__verbosity'])

# %%
parameters = { 
              'xgbregressor__learning_rate': np.arange(0.01, 0.4, 0.02),
              'xgbregressor__max_depth': [4,5,6,7,8],
              'xgbregressor__gamma': [0.5,0.6,0.7,0.8,0.9]
}

# %%
grid = GridSearchCV(estimator=xgb, param_grid=parameters,scoring='r2', cv=10)
grid.fit(X_train_full,y_train_full)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('minmaxscaler',
#                                         MinMaxScaler(copy=True,
#                                                      feature_range=(0, 1))),
#                                        ('xgbregressor',
#                                         XGBRegressor(base_score=None,
#                                                      booster=None,
#                                                      colsample_bylevel=None,
#                                                      colsample_bynode=None,
#                                                      colsample_bytree=None,
#                                                      gamma=None, gpu_id=None,
#                                                      importance_type='gain',
#                                                      interaction_constraints=None,
#                                                      learning_rate=No...
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'xgbregressor__gamma': [0.5, 0.6, 0.7, 0.8, 0.9],
#                          'xgbregressor__learning_rate': array([0.01, 0.03, 0.05, 0.07, 0.09, 0.11, 0.13, 0.15, 0.17, 0.19, 0.21,
#        0.23, 0.25, 0.27, 0.29, 0.31, 0.33, 0.35, 0.37, 0.39]),
#                          'xgbregressor__max_depth': [4, 5, 6, 7, 8]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='r2', verbose=0)

# %%
grid.best_params_
# Out:
# {'xgbregressor__gamma': 0.5,
#  'xgbregressor__learning_rate': 0.12999999999999998,
#  'xgbregressor__max_depth': 4}

# %%
xgb.set_params(**grid.best_params_)
# Out:
# Pipeline(memory=None,
#          steps=[('minmaxscaler', MinMaxScaler(copy=True, feature_range=(0, 1))),
#                 ('xgbregressor',
#                  XGBRegressor(base_score=None, booster=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, gamma=0.5, gpu_id=None,
#                               importance_type='gain',
#                               interaction_constraints=None,
#                               learning_rate=0.12999999999999998,
#                               max_delta_step=None, max_depth=4,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, n_estimators=100,
#                               n_jobs=None, num_parallel_tree=None,
#                               objective='reg:squarederror', random_state=None,
#                               reg_alpha=None, reg_lambda=None,
#                               scale_pos_weight=None, subsample=None,
#                               tree_method=None, validate_parameters=None,
#                               verbosity=None))],
#          verbose=False)

# %%
xgb.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('minmaxscaler', MinMaxScaler(copy=True, feature_range=(0, 1))),
#                 ('xgbregressor',
#                  XGBRegressor(base_score=0.5, booster='gbtree',
#                               colsample_bylevel=1, colsample_bynode=1,
#                               colsample_bytree=1, gamma=0.5, gpu_id=-1,
#                               importance_type='gain',
#                               interaction_constraints='',
#                               learning_rate=0.12999999999999998,
#                               max_delta_step=0, max_depth=4, min_child_weight=1,
#                               missing=nan, monotone_constraints='()',
#                               n_estimators=100, n_jobs=24, num_parallel_tree=1,
#                               objective='reg:squarederror', random_state=0,
#                               reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                               subsample=1, tree_method='exact',
#                               validate_parameters=1, verbosity=None))],
#          verbose=False)

# %%
y_val_pred_xgb=xgb.predict(X_val)

# %%
xgb.score(X_val,y_val)
# Out:
# 0.8695409101811188

# %%
xgb.score(X_train,y_train)
# Out:
# 0.9836067209416567

# %%
y_test_pred_xgb=xgb.predict(df_test)

# %%
y_test_pred_xgb
# Out:
# array([124908.2 , 147166.8 , 182914.5 , ..., 176428.03, 122524.07,
#        224901.03], dtype=float32)

# %%
scores_XGB=cross_validate(xgb,X_train_full,y_train_full,cv=rkf,scoring=['r2'])
scores_XGB['test_r2'].mean()
# Out:
# 0.8672284548188988

# %%
scores_XGB['test_r2']
# Out:
# array([0.86954091, 0.88196855, 0.94058559, 0.80655996, 0.61233827,
#        0.90428982, 0.85540793, 0.87526131, 0.9000434 , 0.91970853,
#        0.91918478, 0.91167286, 0.88847558, 0.79991326, 0.92926996,
#        0.86617909, 0.91710151, 0.89586053, 0.87439474, 0.62469793,
#        0.91159437, 0.78401343, 0.90473319, 0.90504358, 0.7468461 ,
#        0.83069829, 0.9382405 , 0.87300082, 0.92670162, 0.89440517,
#        0.83885182, 0.80186604, 0.77270374, 0.85217331, 0.91890933,
#        0.87649926, 0.9205787 , 0.91867438, 0.92690144, 0.91075362,
#        0.8920965 , 0.89832096, 0.91479655, 0.67849835, 0.91900444,
#        0.8754271 , 0.9103126 , 0.81686626, 0.91210877, 0.89834798])

# %% [markdown]
# ### GBR

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
# GBR=make_pipeline(sc,GradientBoostingRegressor())

# %%
# GBR.get_params().keys()

# %%
# parameters = {
#     'gradientboostingregressor__max_depth': [80, 90, 100, 110],
#     'gradientboostingregressor__max_features': [2, 3],
#     'gradientboostingregressor__min_samples_leaf': [3, 4, 5],
#     'gradientboostingregressor__min_samples_split': [8, 10, 12],
#     'gradientboostingregressor__n_estimators': [100, 200, 300, 1000]
# }

# %%
# grid = GridSearchCV(estimator=GBR, param_grid=parameters,scoring='r2', cv=10)
# grid.fit(X_train_full,y_train_full)

# %%
GBR=GradientBoostingRegressor()
GBR.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
y_val_pred_gbr=GBR.predict(X_val)

# %%
GBR.score(X_val,y_val)
# Out:
# 0.9099533924230032

# %%
GBR.score(X_train,y_train)
# Out:
# 0.9648118163589913

# %%
y_test_pred_gbr=GBR.predict(df_test)

# %%
y_test_pred_gbr
# Out:
# array([122889.50823998, 158084.80236004, 181205.54710868, ...,
#        170297.86520637, 128716.8489225 , 229360.04224436])

# %%
scores_GBR=cross_validate(GBR,X_train_full,y_train_full,cv=rkf,scoring=['r2','neg_mean_squared_log_error'])
scores_GBR['test_r2'].mean()
# Out:
# 0.887398773131251

# %%
np.sqrt(abs(scores_GBR['test_neg_mean_squared_log_error'])).mean()
# Out:
# 0.12988583953115523

# %%
scores_GBR['test_r2']
# Out:
# array([0.90773097, 0.88330455, 0.94118964, 0.92182617, 0.63927867,
#        0.89788177, 0.87822659, 0.90181067, 0.8937344 , 0.92919974,
#        0.92526023, 0.92714702, 0.8671504 , 0.92751688, 0.92388031,
#        0.88372798, 0.92280633, 0.88373868, 0.89684696, 0.74296191,
#        0.91004235, 0.82286998, 0.90043268, 0.904522  , 0.87349007,
#        0.89028206, 0.93446606, 0.87265941, 0.90511814, 0.90165995,
#        0.85860737, 0.93264752, 0.7443083 , 0.85460172, 0.92605549,
#        0.87861915, 0.92370591, 0.91463773, 0.91152198, 0.89485525,
#        0.86098114, 0.90187634, 0.92318407, 0.76384892, 0.90990672,
#        0.91841629, 0.91063696, 0.89645085, 0.91894159, 0.91537281])

# %%
#xgb regressor is very good algorithm for complicated features, but easy overfitting. lgbm, gbr and random forest regressors are all good to go. In this dataset, GBR has the best score to predict test data.

# %%
answer=df_test.copy()
answer['SalePrice']=y_test_pred_gbr
answer=answer['SalePrice']

# %%
answer.to_csv("house_price_prediction_answers.csv")

# %% [markdown]
# ### voting (Just tried)

# %%
from sklearn.ensemble import VotingRegressor
estimators=[('GBR', GBR), ('rf', Rf), ('LGBM', LGBM),('xgb',xgb)]
ensemble = VotingRegressor(estimators)

# %%
ensemble.fit(X_train,y_train)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# VotingRegressor(estimators=[('GBR',
#                              GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0,
#                                                        criterion='friedman_mse',
#                                                        init=None,
#                                                        learning_rate=0.1,
#                                                        loss='ls', max_depth=3,
#                                                        max_features=None,
#                                                        max_leaf_nodes=None,
#                                                        min_impurity_decrease=0.0,
#                                                        min_impurity_split=None,
#                                                        min_samples_leaf=1,
#                                                        min_samples_split=2,
#                                                        min_weight_fraction_leaf=0.0,
#                                                        n_estimators=100,
#                                                        n_iter_no_change=...
#                                                            learning_rate=0.12999999999999998,
#                                                            max_delta_step=0,
#                                                            max_depth=4,
#                                                            min_child_weight=1,
#                                                            missing=nan,
#                                                            monotone_constraints='()',
#                                                            n_estimators=100,
#                                                            n_jobs=24,
#                                                            num_parallel_tree=1,
#                                                            objective='reg:squarederror',
#                                                            random_state=0,
#                                                            reg_alpha=0,
#                                                            reg_lambda=1,
#                                                            scale_pos_weight=1,
#                                                            subsample=1,
#                                                            tree_method='exact',
#                                                            validate_parameters=1,
#                                                            verbosity=None))],
#                                       verbose=False))],
#                 n_jobs=None, weights=None)

# %%
ensemble.score(X_val,y_val)
# Out:
# 0.8986776438825379

# %%
scores_voting=cross_validate(ensemble,X_train_full,y_train_full,cv=rkf,scoring=['r2'])
scores_voting['test_r2'].mean()
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.1 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# 0.8812836515282615

# %%
y_pred_ensemble=ensemble.predict(df_test)

# %%
answer=df_test.copy()
answer['SalePrice']=y_pred_ensemble
answer=answer['SalePrice']

# %%
answer.to_csv("house_price_prediction_answers_ensemble.csv")
